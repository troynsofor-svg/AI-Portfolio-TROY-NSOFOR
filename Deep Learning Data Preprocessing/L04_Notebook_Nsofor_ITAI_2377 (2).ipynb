# %% [markdown]
# # ITAI 2377 Lab 04: Deep Learning Data Preprocessing
#
# **Instructor:** Mr. Rajan
# **Date:** 2/24/2026
#
# ## Introduction
#
# Welcome to Lab 04!  We'll explore the critical role of data preprocessing in deep learning. Even though models can extract features, preprocessing is essential for optimal performance. We'll cover various data types and apply preprocessing techniques. Resources in Google Colab are limited, so efficient coding is key!
#
# ## Why Preprocess?
#
# Why preprocess when models extract features?
#
# *   **Standardization:** Models need consistent data formats and ranges.
# *   **Noise/Errors:** Raw data is messy. Preprocessing cleans it up.
# *   **Efficiency:** Cleaner data means faster training.
# *   **Results:** Good preprocessing helps models perform their best.
#
# Think of preprocessing as a personal trainer for your model.
#
# ## Data Types and Preprocessing Techniques
#
# ### 1. Image Data

# %%
import matplotlib.pyplot as plt
import os

# Example plot
plt.plot([1,2,3], [4,5,6])
plt.title("Sample Graph")

# Show inside notebook
plt.show()

# Create the 'results' directory if it doesn't exist
os.makedirs('results', exist_ok=True)

# Save to results folder
plt.plot(x, y)
fig.savefig("results/graph.png")
plt.show()

fig, ax = plt.subplots()
ax.plot(x, y)

fig.savefig("results/graph.png")  # more reliable
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [4, 5, 6]

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("Test Graph")

fig.savefig("results/test_graph.png")  # save first
plt.show()

# %%
import cv2
import numpy as np
from skimage import data, img_as_float
import matplotlib.pyplot as plt

# %%
image = data.camera()
resized_image = cv2.resize(image, (128, 128))
gray_image = image # Corrected: image is already grayscale
normalized_image = img_as_float(image)

# %%
import cv2
import numpy as np
from skimage import data, img_as_float
import matplotlib.pyplot as plt

# Load a sample image (replace with your image path if you have one)
image = data.camera()  # Or use: image = cv2.imread("path/to/your/image.jpg")

# Resizing (Student Code: Resize the image to (128, 128))
# Hint: Use cv2.resize()
# YOUR CODE HERE
resized_image = cv2.resize(image, (128, 128))


# Color space conversion (to grayscale)
gray_image = image # Corrected: image is already grayscale

# Normalization (pixel values 0-1)
normalized_image = img_as_float(image)

# Display images
plt.figure(figsize=(12, 6))

plt.subplot(1, 4, 1), plt.imshow(image), plt.title("Original")
plt.subplot(1, 4, 2), plt.imshow(resized_image), plt.title("Resized")
plt.subplot(1, 4, 3), plt.imshow(gray_image, cmap='gray'), plt.title("Grayscale")
plt.subplot(1, 4, 4), plt.imshow(normalized_image), plt.title("Normalized")
plt.show()

# Data Augmentation (rotation - Student Code: Rotate by 30 degrees)
# Hint: Use cv2.getRotationMatrix2D and cv2.warpAffine
angle = 30 #YOUR CODE HERE
rows, cols = image.shape[:2]
M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
rotated_image = cv2.warpAffine(image, M, (cols, rows))

plt.imshow(rotated_image), plt.title("Rotated")
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 4, 1), plt.imshow(image), plt.title("Original")
plt.subplot(1, 4, 2), plt.imshow(resized_image), plt.title("Resized")
plt.subplot(1, 4, 3), plt.imshow(gray_image, cmap='gray'), plt.title("Grayscale")
plt.subplot(1, 4, 4), plt.imshow(normalized_image), plt.title("Normalized")
plt.show()

angle = 30
rows, cols = image.shape[:2]
M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
rotated_image = cv2.warpAffine(image, M, (cols, rows))
plt.imshow(rotated_image), plt.title("Rotated")
plt.show()

# %% [markdown]
# ### 2. Text Data

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

# %%
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
# Out:
# True

# %%
import nltk
nltk.download('punkt_tab', quiet=True) # Explicitly download punkt_tab as suggested by the error

text = "This is a fun example sentence with stop words and punctuation!"
tokens = word_tokenize(text.lower())

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)

text = "This is a fun example sentence with stop words and punctuation!"

# Tokenization (lowercase)
tokens = word_tokenize(text.lower())

# Stop word removal (Student Code: Remove stop words and punctuation)
# Hint: Use the 'stop_words' set and list comprehension
stop_words = set(stopwords.words('english'))
# YOUR CODE HERE
filtered_tokens = [w for w in tokens if not w in stop_words and w not in string.punctuation]


# Lemmatization (Student Code: Lemmatize the filtered tokens)
# Hint: Use WordNetLemmatizer()
lemmatizer = WordNetLemmatizer()
# YOUR CODE HERE
lemmatized_tokens = [lemmatizer.lemmatize(w) for w in filtered_tokens]


print("Original:", text)
print("Tokens:", tokens)
print("Filtered:", filtered_tokens)
print("Lemmatized:", lemmatized_tokens)
# Out:
# Original: This is a fun example sentence with stop words and punctuation!
# Tokens: ['this', 'is', 'a', 'fun', 'example', 'sentence', 'with', 'stop', 'words', 'and', 'punctuation', '!']
# Filtered: ['fun', 'example', 'sentence', 'stop', 'words', 'punctuation']
# Lemmatized: ['fun', 'example', 'sentence', 'stop', 'word', 'punctuation']

# %%
print("Original:", text)
print("Tokens:", tokens)
print("Filtered:", filtered_tokens)
print("Lemmatized:", lemmatized_tokens)
# Out:
# Original: This is a fun example sentence with stop words and punctuation!
# Tokens: ['this', 'is', 'a', 'fun', 'example', 'sentence', 'with', 'stop', 'words', 'and', 'punctuation', '!']
# Filtered: ['fun', 'example', 'sentence', 'stop', 'words', 'punctuation']
# Lemmatized: ['fun', 'example', 'sentence', 'stop', 'word', 'punctuation']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(w) for w in filtered_tokens]

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [w for w in tokens if not w in stop_words and w not in string.punctuation]

# %% [markdown]
# ### 3. Time Series Data

# %%
import pandas as pd
import numpy as np

# %%
data = {'Date': pd.to_datetime(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05']),
        'Value': [10, 12, 15, 18, 20]}
df = pd.DataFrame(data)

# %%
df['Value'].fillna(method='bfill', inplace=True)
# Out:
# /tmp/ipython-input-2568032519.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Value'].fillna(method='bfill', inplace=True)
# /tmp/ipython-input-2568032519.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Value'].fillna(method='bfill', inplace=True)

# %%
import pandas as pd
import numpy as np

# Sample data (with a missing value)
data = {'Date': pd.to_datetime(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05']),
        'Value': [10, 12, 15, np.nan, 18]}

df = pd.DataFrame(data)

# Missing value handling (Student Code: Use backward fill to fill missing values)
# Hint: Use fillna() with method='bfill'
# YOUR CODE HERE
df['Value'].fillna(method='bfill', inplace=True)

# Normalization (min-max scaling - Student Code: Normalize the 'Value' column)
# YOUR CODE HERE
min_val = df['Value'].min()
max_val = df['Value'].max()
df['Normalized'] = (df['Value'] - min_val) / (max_val - min_val)

print(df)
# Out:
#         Date  Value  Normalized
# 0 2024-01-01   10.0       0.000
# 1 2024-01-02   12.0       0.250
# 2 2024-01-03   15.0       0.625
# 3 2024-01-04   18.0       1.000
# 4 2024-01-05   18.0       1.000
# /tmp/ipython-input-3069143717.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Value'].fillna(method='bfill', inplace=True)
# /tmp/ipython-input-3069143717.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Value'].fillna(method='bfill', inplace=True)

# %%
min_val = df['Value'].min()
max_val = df['Value'].max()
df['Normalized'] = (df['Value'] - min_val) / (max_val - min_val)
print(df)
# Out:
#         Date  Value  Normalized
# 0 2024-01-01     10         0.0
# 1 2024-01-02     12         0.2
# 2 2024-01-03     15         0.5
# 3 2024-01-04     18         0.8
# 4 2024-01-05     20         1.0

# %% [markdown]
# ### 4. Optional: Video Data (Simplified)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
video_path = "your_video.mp4"
cap = cv2.VideoCapture(video_path)

# %%
if not cap.isOpened():
    print("Error opening video")
else:
    ret, frame = cap.read()
    if ret:
        resized_frame = cv2.resize(frame, (80, 60))
        gray_frame = cv2.cvtColor(resized_frame, cv2.COLOR_BGR2GRAY)
# Out:
# Error opening video

# %%
import cv2
import matplotlib.pyplot as plt # Import matplotlib

# Load a video (replace with your video path or a small sample video if possible)
video_path = "your_video.mp4"  # Replace with your video file path (or upload one to Colab)
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error opening video")
else:
    ret, frame = cap.read()  # Read a single frame
    if ret:
        # Resize the frame (for faster processing - Student Code: Resize to (80, 60))
        # YOUR CODE HERE
        resized_frame = cv2.resize(frame, (80, 60))

        # Convert to grayscale
        gray_frame = cv2.cvtColor(resized_frame, cv2.COLOR_BGR2GRAY)  # OpenCV uses BGR

        # Display the frame (optional)
        plt.imshow(gray_frame, cmap='gray')
        plt.title("Video Frame (Grayscale)")
        plt.show()

    cap.release()
cv2.destroyAllWindows()
# Out:
# Error opening video

# %%
frame = cv2.imread("your_image.jpg")

# %%
import numpy as np # Ensure numpy is imported for np.zeros

# Ensure gray_frame is defined for plotting, even if video loading failed
# If gray_frame and cap are not defined from previous execution due to video loading failure, create placeholders
if 'gray_frame' not in locals() and 'gray_frame' not in globals():
    print("Warning: 'gray_frame' was not defined by video loading. Displaying a black placeholder image.")
    gray_frame = np.zeros((60, 80), dtype=np.uint8) # Create a dummy black image

if 'cap' not in locals() and 'cap' not in globals():
    print("Warning: 'cap' was not defined by video loading. Skipping cap.release().")
    cap = None


plt.imshow(gray_frame, cmap='gray')
plt.title("Video Frame (Grayscale)")
plt.show()

# Safely attempt to release cap if it was opened
if cap is not None and cap.isOpened():
    cap.release()
cv2.destroyAllWindows()
# Out:
# Warning: 'gray_frame' was not defined by video loading. Displaying a black placeholder image.

# %% [markdown]
# ### 5. Optional: Audio Data (Simplified)

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

# %%
audio_path = "your_audio.wav"
y, sr = librosa.load(audio_path, duration=5)
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)

# %%
from google.colab import files

# This will open a file picker dialog
# If you run this, a button will appear to browse and upload your file.
# Once uploaded, the filename will be printed.
# Make sure to upload a WAV file, for example, 'your_audio.wav'.
# files.upload()

# %%
import numpy as np
from scipy.io.wavfile import write as write_wav

# Parameters for the dummy audio file
sr = 22050  # sample rate
duration = 5  # seconds
frequency = 440  # Hz (A4 note)

# Generate a sine wave
t = np.linspace(0, duration, int(sr * duration), False)
audio_data = 0.5 * np.sin(2 * np.pi * frequency * t)

# Convert to 16-bit PCM format
audio_data_int16 = (audio_data * 32767).astype(np.int16)

# Define the path where the dummy audio will be saved
dummy_audio_path = '/content/your_audio.wav'

# Write the audio data to a WAV file
write_wav(dummy_audio_path, sr, audio_data_int16)

print(f"Dummy audio file created at: {dummy_audio_path}")
# Out:
# Dummy audio file created at: /content/your_audio.wav

# %%
# !apt-get install -y ffmpeg > /dev/null 2>&1 # Install ffmpeg for broader audio support
import librosa
import numpy as np
import matplotlib.pyplot as plt

# Load an audio file (replace with your audio path)
audio_path = "/content/your_audio.wav"  # This path now points to the generated dummy audio file
y, sr = librosa.load(audio_path, duration=5)  # Load a maximum of 5 seconds

# Feature extraction (MFCCs - Student Code: Extract 20 MFCCs)
# Hint: Use librosa.feature.mfcc() with n_mfcc=20
# YOUR CODE HERE
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)

# Display MFCCs (optional)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
plt.colorbar()
plt.title('MFCCs')
plt.tight_layout()
plt.show()

# Normalize MFCCs (example)
mfccs_normalized = (mfccs - np.mean(mfccs)) / np.std(mfccs)

print("MFCCs shape:", mfccs.shape)
print("Normalized MFCCs shape:", mfccs_normalized.shape)
# Out:
# MFCCs shape: (20, 216)
# Normalized MFCCs shape: (20, 216)

# %% [markdown]
# After uploading, modify the `audio_path` variable in the code below to reflect the actual path of your uploaded file (e.g., `/content/your_audio.wav`). If you manually uploaded, it would be in the `/content/` directory.

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

# Load an audio file (replace with your audio path)
audio_path = "/content/your_audio.wav"  # <--- UPDATE THIS PATH with your actual file path
y, sr = librosa.load(audio_path, duration=5)  # Load a maximum of 5 seconds

# Feature extraction (MFCCs - Student Code: Extract 20 MFCCs)
# Hint: Use librosa.feature.mfcc() with n_mfcc=20
# YOUR CODE HERE
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)

# Display MFCCs (optional)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
plt.colorbar()
plt.title('MFCCs')
plt.tight_layout()
plt.show()

# Normalize MFCCs (example)
mfccs_normalized = (mfccs - np.mean(mfccs)) / np.std(mfccs)

print("MFCCs shape:", mfccs.shape)
print("Normalized MFCCs shape:", mfccs_normalized.shape)
# Out:
# MFCCs shape: (20, 216)
# Normalized MFCCs shape: (20, 216)

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

# Load an audio file (replace with your audio path)
audio_path = "your_audio.wav"  # Replace with your audio file path (or upload one to Colab)
y, sr = librosa.load(audio_path, duration=5)  # Load a maximum of 5 seconds

# Feature extraction (MFCCs - Student Code: Extract 20 MFCCs)
# Hint: Use librosa.feature.mfcc() with n_mfcc=20
# YOUR CODE HERE
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)

# Display MFCCs (optional)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
plt.colorbar()
plt.title('MFCCs')
plt.tight_layout()
plt.show()

# Normalize MFCCs (example)
mfccs_normalized = (mfccs - np.mean(mfccs)) / np.std(mfccs)

print("MFCCs shape:", mfccs.shape)
print("Normalized MFCCs shape:", mfccs_normalized.shape)
# Out:
# MFCCs shape: (20, 216)
# Normalized MFCCs shape: (20, 216)

# %% [markdown]
# **Tip:** Explore different methods for handling missing values (e.g., backward fill, interpolation).  Consider feature engineering techniques like creating lagged variables.
#
# ## Questions (Markdown Cell)
#
# 1.  Why is data preprocessing still important even with deep learning's feature extraction capabilities?
#
# The reasons why data preprocessing is crucial in deep learning are because it cleans normalizes, and formats data, confirming quicker convergence, higher accuracy, and better generalization.
#
# 2.  Explain the difference between normalization and standardization. When would you choose one over the other?
#
# Normalization scales data to a fixed range (obviously zero to one) applying a min-max. Standardization on the other hand, centers data around an average of zero with a standard deviation of one. I would choose standardization over normalization when I need to deal with outliers and I will choose and use it when I'm using algorithms to manage normal distribution.
#
# 3.  Describe a scenario where data augmentation would be particularly useful.
#
# Data augmentation can be useful when preparing machine learning models on little or unbalanced datasets, like diagnostic radiography for rare disease diagnosis.
#
# 4.  What are some potential challenges or pitfalls to avoid during data preprocessing?  How can you mitigate them?
#
# The challenges or pitfalls to stay away from during data preprocessing are data leakage, having too much capacity in the data, bad data quality, incomplete data, and inappropriate feature engineering. To mitigate the challenges, I can confirm that I have divided data before preprocessing, apply strong scaling, calculate missing values cautiously, and I will also apply cross-validation to preserve robust performance.
#
# 5.  Choose one of the data types covered in the lab (images, text, time series).  Describe a specific real-world application that uses deep learning and explain how preprocessing would be crucial for that application.
#
# The data type that was covered in this lab was images. A real-world application that uses deep learning is medical image processing, like discovering brain tumors or identifying cancer from MRI/CT scans, usually outgoing traditional techiques. Preprocessing is important because raw medical pictures depend on intensity, variation, and sound, which can confuse deep neural networks and minimize accuracy.
#
# ## Deliverables
#
# *   **Completed Notebook (PDF):** This notebook with your code, outputs, and answers to the questions.
# *   **Reflective Journal:** A short journal (1-2 pages) reflecting on your learning experience in this lab.  Consider the following prompts:
#     *   What did you learn in this lab?
#     *   What challenges did you encounter? How did you overcome them?
#     *   Were there any concepts that you already knew?
#     *   Did anything surprise you?
#     *   What are some potential real-world applications of the preprocessing techniques you learned?
#     *   What further learning or exploration would you like to pursue related to data preprocessing?
#
# Remember to save your notebook with the outputs and convert it to PDF before submission. Good luck!
# ```

# %% [markdown]
# <div class="md-recitation">
#   Sources
#   <ol>
#   <li><a href="https://towardsdatascience.com/text-normalization-with-spacy-and-nltk-1302ff430119">https://towardsdatascience.com/text-normalization-with-spacy-and-nltk-1302ff430119</a></li>
#   </ol>
# </div>
